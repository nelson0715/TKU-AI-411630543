# %% [markdown]
# <a href="https://colab.research.google.com/github/nelson0715/TKU-AI-411630543/blob/main/0927.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.plot([9,9.2,9.5,7.5,6.7,7], [9.4,9.2,9.2,9.2,7.1,7.4 ],'yx')
plt.plot([9,9.2,9.6,7.5,6.7,7], [9.4,9.2,9.2,9.2,7.1,7.4 ],'yx')


plt.plot([7.2,7.3,7.2,7.3,7.2,7.3,7.3], [10.3,10.5,9.2,10.2,9.7,10.1,10.1 ],'gx')
plt.plot([6.5,9.0], [7.8,12.5],'b--')
plt.ylabel('H cm')
plt.xlabel('W cm')

plt.legend(('Orange','Lemous'),loc='upper right')
plt.show()
